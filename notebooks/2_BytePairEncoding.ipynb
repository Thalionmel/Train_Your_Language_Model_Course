# %% [markdown]
# ## Load the sequence

# %%
with open("../data/text_sequence.json", "r", encoding="utf-8") as f:
    text_sequence = f.read()

len(text_sequence)
# Out:
# 321697

# %% [markdown]
# ## BPE algorithm

# %% [markdown]
# I am using the [minBPE](https://github.com/karpathy/minbpe) repository to tokenize the sequence of text.

# %%
import sys
sys.path.append('..')

# %% [markdown]
# Start by training the tokenizer on the text sequence that you saved in the previous notebook.

# %%
from minbpe import BasicTokenizer

tokenizer = BasicTokenizer()
tokenizer.train(text_sequence, vocab_size=4096)
# Out:
#   2%|▏         | 76/3840 [00:02<02:05, 29.96it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 from minbpe import BasicTokenizer
#       3 tokenizer = BasicTokenizer()
# ----> 4 tokenizer.train(text_sequence, vocab_size=4096)
#
# File c:\Users\thali\OneDrive\Dokumente\GitHub\Train_Your_Language_Model_Course\notebooks\..\minbpe\basic.py:32, in BasicTokenizer.train(self, text, vocab_size, verbose)
#      30 merges = {}  # (int, int) -> int
#      31 vocab = {idx: bytes([idx]) for idx in range(256)}  # int -> bytes
# ---> 32 for i in tqdm(range(num_merges), total=num_merges):
#      33     # count up the number of times every consecutive pair appears
#      34     stats = get_stats(ids)
#      35     # find the pair with the highest count
#
# File c:\Python311\Lib\site-packages\tqdm\std.py:1191, in tqdm.__iter__(self)
# ...

# %% [markdown]
# Visualize the vocabulary.

# %%
vocab = tokenizer.vocab
vocab
# Out:
# {0: b'\x00',
#  1: b'\x01',
#  2: b'\x02',
#  3: b'\x03',
#  4: b'\x04',
#  5: b'\x05',
#  6: b'\x06',
#  7: b'\x07',
#  8: b'\x08',
#  9: b'\t',
#  10: b'\n',
#  11: b'\x0b',
#  12: b'\x0c',
#  13: b'\r',
#  14: b'\x0e',
#  15: b'\x0f',
#  16: b'\x10',
#  17: b'\x11',
#  18: b'\x12',
#  19: b'\x13',
#  20: b'\x14',
#  21: b'\x15',
#  22: b'\x16',
#  23: b'\x17',
#  24: b'\x18',
#  25: b'\x19',
#  26: b'\x1a',
#  27: b'\x1b',
#  28: b'\x1c',
#  29: b'\x1d',
#  30: b'\x1e',
#  31: b'\x1f',
#  32: b' ',
#  33: b'!',
#  34: b'"',
#  35: b'#',
#  36: b'$',
#  37: b'%',
#  38: b'&',
#  39: b"'",
#  40: b'(',
#  41: b')',
#  42: b'*',
#  43: b'+',
#  44: b',',
#  45: b'-',
#  46: b'.',
#  47: b'/',
#  48: b'0',
#  49: b'1',
#  50: b'2',
#  51: b'3',
#  52: b'4',
#  53: b'5',
#  54: b'6',
#  55: b'7',
#  56: b'8',
#  57: b'9',
#  58: b':',
#  59: b';',
#  60: b'<',
#  61: b'=',
#  62: b'>',
#  63: b'?',
#  64: b'@',
#  65: b'A',
#  66: b'B',
#  67: b'C',
#  68: b'D',
#  69: b'E',
# ...

# %% [markdown]
# Test the tokenizer.

# %%
tokenizer.encode("Herrin Rondra")
# Out:
# [1020, 1388]

# %%
tokenizer.decode([1020, 1388])
# Out:
# 'Herrin Rondra'

# %% [markdown]
# Add special tokens to the vocabulary. These tokens are going to be used a lot in the fine-tuning step.

# %%
max_vocab_id = list(tokenizer.vocab.keys())[-1]
tokenizer.special_tokens = {
    "<|startoftext|>": max_vocab_id + 1,
    "<|separator|>": max_vocab_id + 2,
    "<|endoftext|>": max_vocab_id + 3,
    "<|unk|>": max_vocab_id + 4,
    "<|padding|>": max_vocab_id + 5,
}

# %% [markdown]
# I have more than 618K tokens for training and validation. This is pretty good, but if you can add more, that would be even better.

# %%
len(tokenizer.encode(text_sequence))
# Out:
# 70220

# %% [markdown]
# Save the tokenizer

# %%
tokenizer.save(file_prefix="../output/tokenizer/my_tokenizer")
